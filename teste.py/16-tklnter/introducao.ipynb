# %%
import tkinter



#GERAR UM APLICATIVO
app = tkinter.Tk()



#alterar o titulo
app.title("App do professor")

#alterar a resolução
app.geometry("400x400")

#texto titulo
txt_titulo = tkinter.Label(app, text = "Somar valores ", fg="blue", font=("Helvetica",12,"bold"))
txt_titulo.grid(column=0, row=0, columnspan=3)

#texto valor 1
txt_valor1 = tkinter.Label(app, text="Valor 1 :")
txt_valor1.grid(column=0, row=1)

# entrada valor1  input
input_valor1 = tkinter.Entry(app)
input_valor1.grid(column=1, row=1)

#valor 2
txt_valor2 = tkinter.Label(app, text="Valor 2 :")
txt_valor2.grid(column=0, row=2)


# entrada valor2 input
input_valor2 = tkinter.Entry(app)
input_valor2.grid(column=1, row=2)

#botão
botao = tkinter.Button(app, text="somar", command=acao )
botao.grid(column=0, row=3, columnspan=2)

#funcionamento do botão
def acao():
    v1= int(input_valor1.get())
    v2=int(input_valor2.get())
    soma = v1 +v2

    txt_resultado.configure(text=soma)


#resultado
txt_resultado = tkinter.Label(app, text="")
txt_resultado.grid(column=0, row=4, columnspan=2)



#iniciar - precisa ser a ultima instrução
app.mainloop()
